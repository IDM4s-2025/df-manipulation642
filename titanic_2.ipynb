# %% [markdown]
# # Reading data
# Read the train.csv file as a pandas dataframe.

# %% [markdown]
# # Indexing
# 1. Create a function that returns the name of a passenger given their PassengerId.
# 2. Create a function that returns the PassengerId of a passenger given their Name.
# 3. Print a message with the ID of passenger **Montvila, Rev. Juozas** with the following format: 'The ID pf passenger Montvila, Rev. Juozas is ##'
# 4. Print a message with the name of the passenger with ID **42** with the following format: 'The passenger with ID 42 is X'

# %%
import pandas as pd

titanic = pd.read_csv("train.csv")

# %%
import titanic_fns

# %%
# 3. Print a message with the ID of passenger **Montvila, Rev. Juozas** with the following format: 'The ID pf passenger Montvila, Rev. Juozas is ##'
id_juozas = titanic_fns.name_to_id(titanic, 'Montvila, Rev. Juozas')
print("The ID of passenger Montvila, Rev. Juozas is", id_juozas)
# Out:
# The ID of passenger Montvila, Rev. Juozas is 887

# %%
# 4. Print a message with the name of the passenger with ID **42** with the following format: 'The passenger with ID 42 is X'

id_42 = titanic_fns.id_to_name(titanic, 42)
print("The passenger with ID 42 is", id_42)
# Out:
# The passenger with ID 42 is Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)

# %% [markdown]
# 5. Print all information about the oldest passenger.

# %%
print("The oldest passenger was", int(titanic.loc[titanic.Age.idxmax(), "Age"]), "years old")

titanic.loc[titanic.Age.idxmax()]
# Out:
# The oldest passenger was 80 years old
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Sex                                            male
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# Name: 630, dtype: object

# %% [markdown]
# # Subseting
# We are asked to share data for analysis by a third party. Since our dataset contains personal details, we only want to share with them the following information: ticket classes, fares and port of embarkation. We are asked to deliver a sample of the first 100 rows of this dataset.
#
# 6. Create and save the new dataset in **data/port_fares.csv**.

# %%
new_data = titanic.iloc[:100]
new_data = new_data.loc[:, ['Pclass', 'Fare', 'Embarked']]
print(new_data)
new_data.to_csv('port_fares.csv', index=False)
# Out:
#     Pclass     Fare Embarked
# 0        3   7.2500        S
# 1        1  71.2833        C
# 2        3   7.9250        S
# 3        1  53.1000        S
# 4        3   8.0500        S
# ..     ...      ...      ...
# 95       3   8.0500        S
# 96       1  34.6542        C
# 97       1  63.3583        C
# 98       2  23.0000        S
# 99       2  26.0000        S
#
# [100 rows x 3 columns]

# %% [markdown]
# # Counting
# 7. We want to know if there were any survivors over the age of 60, print all of their information.
# 8. How many people over 60 survived?
# 9. What percentage of people over 60 survived?

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 7. We want to know if there were any survivors over the age of 60, print all of their information.
titanic.loc[(titanic.Survived == 1) & (titanic.Age > 60)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 570          571         1       2                         Harris, Mr. George
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# 275  female  63.0      1      0        13502  77.9583    D7        S
# 483  female  63.0      0      0         4134   9.5875   NaN        S
# 570    male  62.0      0      0  S.W./PP 752  10.5000   NaN        S
# 630    male  80.0      0      0        27042  30.0000   A23        S
# 829  female  62.0      0      0       113572  80.0000   B28      NaN

# %%
# 8. How many people over 60 survived?
over_60_s = titanic.loc[(titanic.Survived == 1) & (titanic.Age > 60)]
print(len(over_60_s), " people over 60 years old survived")
# Out:
# 5  people over 60 years old survived

# %%
# 9. What percentage of people over 60 survived?
over_60_n = titanic.loc[(titanic.Survived == 0) & (titanic.Age > 60)]
all_over_60 = len(over_60_s) + len(over_60_n)
per_60 = (len(over_60_s)/all_over_60)*100

print(round(per_60,2), "% over 60 years old survived")
# Out:
# 22.73 % over 60 years old survived

# %%
titanic.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# Cuántas personas de cada clase sobrevivieron/fallecieron
titanic.groupby("Survived")["Pclass"].value_counts()
# Out:
# Survived  Pclass
# 0         3         372
#           2          97
#           1          80
# 1         1         136
#           3         119
#           2          87
# Name: count, dtype: int64

# %%
# Promedio de edad por clase de las personas que sobrevivieron/fallecieron
titanic.groupby(["Survived", "Pclass"])["Age"].mean()
# Out:
# Survived  Pclass
# 0         1         43.695312
#           2         33.544444
#           3         26.555556
# 1         1         35.368197
#           2         25.901566
#           3         20.646118
# Name: Age, dtype: float64

# %%
# Promedio de edad por género de las personas que sobrevivieron/fallecieron
titanic.groupby(["Survived", "Sex"])["Age"].mean()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %% [markdown]
# # Women and children first?
# 10. Find out if women and children were more likely to survive.

# %% [markdown]
# 11. Write a function that returns the percentage of people that survived from a subset given as a boolean Pandas series.

# %% [markdown]
# # Summarizing
#
# 12. What is the median age of the passengers?
# 13. How many passengers embarked from each port?

# %% [markdown]
# 14. Generate two hypotheses about how does the survival rate differ among groups of passengers. Write your code to explore both hypotheses.

# %% [markdown]
# # Vectorizing

# %%
import time
import numpy as np

# Código con bucle for
start = time.time()

total = 0
for i in np.arange(10000000):
    total = i + total

print(total)
end = time.time()
print(end - start)
# Out:
# 49999995000000
# 2.1638870239257812

# %%
start = time.time()

print(np.sum(np.arange(10000000)))

end = time.time()
print(end - start)
# Out:
# 49999995000000
# 0.1309511661529541
